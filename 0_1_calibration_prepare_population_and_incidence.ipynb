# %% [markdown]
# # Prepare Projected Incidence Data for Calibration Year to Compare to Results of Simulation

# %%
from matplotlib.colors import BoundaryNorm, ListedColormap
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from country_config import *
from files_config import *
from run_config import *
from utils import *

# %% [markdown]
# ## Import Data From Rasters

# %%
# Read rasters
initial_observed_population_raster, metadata = read_raster(f"{data_path}/{country_code}_initpopulation_{initial_year}.asc")
# initial_observed_population_raster, metadata = read_raster(f"{data_path}/{input_population_file}")
final_observed_population_raster, _ = read_raster(f"{data_path}/{country_code}_population_{final_observed_year}.asc")
districts_raster, _ = read_raster(f"{data_path}/{country_code}_district.asc")

nodata = metadata["NODATA_value"]

if initial_observed_population_raster.shape != districts_raster.shape:
    raise ValueError(
        f"Population raster and district raster have different shapes: {initial_observed_population_raster.shape} vs {districts_raster.shape}"
    )

if final_observed_population_raster.shape != districts_raster.shape:
    raise ValueError(
        f"Final population raster and district raster have different shapes: {final_observed_population_raster.shape} vs {districts_raster.shape}"
    )


# Get unique district IDs from full raster, excluding nodata
valid_districts = districts_raster[districts_raster != nodata]
unique_districts = np.unique(valid_districts).astype(int)

print("Unique District IDs:", unique_districts)

# Flatten full rasters
initial_observed_population = initial_observed_population_raster.flatten().astype(int)
final_observed_population = final_observed_population_raster.flatten().astype(int)
district = districts_raster.flatten().astype(int)

# Keep only cells valid in all three rasters (initial population, final population, and district)
valid_mask = (
    (initial_observed_population != nodata) &
    (final_observed_population != nodata) &
    (district != nodata)
)

init_pop_valid = initial_observed_population[valid_mask]
final_pop_valid = final_observed_population[valid_mask]
district_valid = district[valid_mask]

# Sum population values per district by using district ID as bin index and population as weight (zonal sum via bincount)
sum_init_population_per_district = np.bincount(district_valid, weights=init_pop_valid)
sum_final_population_per_district = np.bincount(district_valid, weights=final_pop_valid)

df = pd.DataFrame({
    f"district_id": unique_districts,
    f"init_population": [sum_init_population_per_district[d] for d in unique_districts],
    f"final_population_{final_observed_year}": [sum_final_population_per_district[d] for d in unique_districts],
})

total_init_population = df[f"init_population"].sum()
total_final_population = df[f"final_population_{final_observed_year}"].sum()

print(f"Total Initial Observed Population: {total_init_population:,.0f}")
print(f"Total Final Observed Population ({final_observed_year}): {total_final_population:,.0f}")

df
# Out:
# Unique District IDs: [ 7  9 11 26 32 35]
# Total Initial Population: 19,167,271
# Total Final Observed Population (2020): 24,572,163
#    district_id  init_population  final_population_2020
# 0            7        5042202.0              6464378.0
# 1            9        3126634.0              4008484.0
# 2           11        2561567.0              3284316.0
# 3           26        2170074.0              2781807.0
# 4           32        3712017.0              4758921.0
# 5           35        2554777.0              3274257.0

# %%
# Add comma separators to the numbers in the dataframe for better readability
df_formatted = df.copy()
df_formatted[f"init_population"] = df_formatted[f"init_population"].apply(lambda x: f"{int(x):,}")
df_formatted[f"final_population_{final_observed_year}"] = df_formatted[f"final_population_{final_observed_year}"].apply(lambda x: f"{int(x):,}")
df_formatted
# Out:
#    district_id init_population final_population_2020
# 0            7       5,042,202             6,464,378
# 1            9       3,126,634             4,008,484
# 2           11       2,561,567             3,284,316
# 3           26       2,170,074             2,781,807
# 4           32       3,712,017             4,758,921
# 5           35       2,554,777             3,274,257

# %% [markdown]
# ## Total valid pixels

# %%
print("Total valid pixels:", valid_mask.sum())
# Out:
# Total valid pixels: 6851

# %% [markdown]
# ## Generate Projected Population Raster from observed

# %%
# Force scale target year population raster to 25.09 million
SCALE_FACTOR = TARGET_POPULATION_CALIBRATION_YEAR / df[f"final_population_{final_observed_year}"].sum()

# Start from full raster
target_year_population_projected_raster = final_observed_population_raster.astype(float).copy()

# Scale only valid cells
valid_mask = (
    (initial_observed_population_raster != nodata) &
    (final_observed_population_raster != nodata) &
    (districts_raster != nodata)
)

target_year_population_projected_raster[valid_mask] = final_observed_population_raster[valid_mask] * SCALE_FACTOR

# Keep nodata cells unchanged
target_year_population_projected_raster[~valid_mask] = nodata

write_raster(
    raster=target_year_population_projected_raster,
    file=f"{data_path}/{country_code}_population_projected_{calibration_year}.asc",
    xllcorner=metadata["xllcorner"],
    yllcorner=metadata["yllcorner"],
    cellsize=metadata["cellsize"],
    mask_raster=districts_raster,  # preserve nodata areas
    nodata=nodata,
)


target_population_projected_raster, _ = read_raster(f"{data_path}/{country_code}_population_projected_{calibration_year}.asc")

# Verify that the sum of the scaled population matches the target
target_population_projected_valid = target_population_projected_raster[valid_mask]
sum_target_population_projected_per_district = np.bincount(district_valid, weights=target_population_projected_valid)

print(f"Scale factor: {SCALE_FACTOR}")
print(f"Projected population in {calibration_year}: {target_population_projected_valid.sum():,.3f} (target: {TARGET_POPULATION_CALIBRATION_YEAR:,.3f})")
# Out:
# Scale factor: 1.087265170754402
# Projected population in 2024: 26,716,457.000 (target: 26,716,457.000)

# %% [markdown]
# ## Plot Observed vs Projected Population Map Difference

# %%
observed_pop_raster_path = Path(f"{data_path}/{country_code}_population_{final_observed_year}.asc")
projected_pop_raster_path = Path(f"{data_path}/{country_code}_population_projected_{calibration_year}.asc")

observed_population, _ = read_raster(observed_pop_raster_path)
projected_population, _ = read_raster(projected_pop_raster_path)

# Difference map (Projected - Observed)
population_difference = projected_population - observed_population

# Where sim is nodata but obs exists → sim "contributed 0", so diff = -obs
missing_sim_mask = ~np.isfinite(projected_population) & np.isfinite(observed_population)
population_difference[missing_sim_mask] = -observed_population[missing_sim_mask]

# Where obs is nodata (can't compare) → keep as NaN
population_difference[~np.isfinite(observed_population)] = np.nan

# -----------------------
# Robust linear limits (prevents outliers from crushing contrast)
# -----------------------
combined = np.r_[observed_population[np.isfinite(observed_population)].ravel(), projected_population[np.isfinite(projected_population)].ravel()]

# tweak these if needed
lo, hi = 2, 98
vmin = np.nanpercentile(combined, lo)
vmax = np.nanpercentile(combined, hi)

# -----------------------
# 8-band colormap for Population (Obs/Sim)
# -----------------------
n_bins = 8
bounds = np.r_[-vmax, 0, np.linspace(0, vmax, n_bins)[1:]]

base = plt.get_cmap("viridis", n_bins)        # discretize viridis into 8 colors
bg_white_color = np.array([[1,1,1,1]])
cmap_pop = ListedColormap(np.vstack([bg_white_color, plt.get_cmap("viridis", n_bins)(np.arange(1, n_bins))]))
norm_pop = BoundaryNorm(bounds, cmap_pop.N, clip=True)

# -----------------------
# 8-band diverging for Difference (symmetric, robust)
# -----------------------
dmax = np.nanpercentile(np.abs(population_difference[np.isfinite(population_difference)]), 98)
dbounds = np.linspace(-dmax, dmax, n_bins + 1)

base_d = plt.get_cmap("RdBu_r", n_bins)
cmap_diff = ListedColormap(base_d(np.arange(n_bins)))
norm_diff = BoundaryNorm(dbounds, cmap_diff.N, clip=True)

# -----------------------
# Plot
# -----------------------
fig, axes = plt.subplots(1, 3, figsize=(18, 6), constrained_layout=True)

im0 = axes[0].imshow(observed_population, cmap=cmap_pop, norm=norm_pop, zorder=2)
axes[0].set_title(f"Population Observed in {final_observed_year}")

im1 = axes[1].imshow(projected_population, cmap=cmap_pop, norm=norm_pop, zorder=2)
axes[1].set_title(f"Population Projected in {calibration_year}")

im2 = axes[2].imshow(population_difference, cmap=cmap_diff, norm=norm_diff, zorder=2)
axes[2].set_title(f"Difference in Population (Observed - Projected)")

# Colorbars (banded)
cbar1 = fig.colorbar(im1, ax=axes[:2], shrink=0.85, boundaries=bounds)
cbar1.set_label("Population")
cbar1.set_ticks(bounds)  # show band edges (or use bounds[::2] for fewer ticks)

cbar2 = fig.colorbar(im2, ax=axes[2], shrink=0.85, boundaries=dbounds)
cbar2.set_label("Difference in Population")
cbar2.set_ticks(dbounds)

plt.savefig(f"{data_path}/observed_{final_observed_year}_vs_projected_{calibration_year}_population_pixel_maps.png", dpi=200)
plt.show()

# %% [markdown]
# ### Write to final raster

# %%
write_raster(
    raster=target_year_population_projected_raster,
    file=f"{data_path}/ng-se_population_projected_{calibration_year}.asc",
    xllcorner=metadata["xllcorner"],
    yllcorner=metadata["yllcorner"],
    cellsize=metadata["cellsize"],
    mask_raster=districts_raster,  # preserve nodata areas
    nodata=nodata,
)

print(f"Wrote projected population raster for {calibration_year} to {data_path}/ng-se_population_projected_{calibration_year}.asc")

print(f"Projected population in {calibration_year}: {target_year_population_projected_raster[valid_mask].sum():,.0f} (target: {TARGET_POPULATION_CALIBRATION_YEAR:,.0f})")
# Out:
# Wrote projected population raster for 2024 to data/ng-se_population_projected_2024.asc
# Projected population in 2024: 26,716,457 (target: 26,716,457)

# %% [markdown]
# ### Write to csv

# %%
df[f'final_population_{calibration_year}_projected'] = df[f"final_population_{final_observed_year}"] * SCALE_FACTOR

init_pop_sum = df['init_population'].sum()
final_observed_sum = df[f"final_population_{final_observed_year}"].sum()
final_projected_sum = df[f"final_population_{calibration_year}_projected"].sum()


print(f'Initial population sum: {init_pop_sum:,.2f}')
print(f'Final population observed sum ({final_observed_year}): {final_observed_sum:,.2f}')
print(f'Final population projected sum ({calibration_year}): {final_projected_sum:,.2f}')

df.to_csv(f"{data_path}/population_per_district_projected.csv", index=False)

print(f"Wrote projected population per district to {data_path}/population_per_district_projected.csv")
# Out:
# Initial population sum: 19,167,271.00
# Final population observed sum (2020): 24,572,163.00
# Final population projected sum (2024): 26,716,457.00
# Wrote projected population per district to data/population_per_district_projected.csv

# %% [markdown]
# ### Scale incidence from population

# %%
pop_df = pd.read_csv(f"{data_path}/population_per_district_projected.csv")
pop_df
# Out:
#    district_id  init_population  final_population_2020  \
# 0            7        5042202.0              6464378.0
# 1            9        3126634.0              4008484.0
# 2           11        2561567.0              3284316.0
# 3           26        2170074.0              2781807.0
# 4           32        3712017.0              4758921.0
# 5           35        2554777.0              3274257.0
#
#    final_population_2024_projected
# 0                     7.028493e+06
# 1                     4.358285e+06
# 2                     3.570922e+06
# 3                     3.024562e+06
# 4                     5.174209e+06
# 5                     3.559986e+06

# %%
incidence_path =(f"{data_path}/Incidence Data")
# incidence_per_1000 = pd.read_csv(f"{incidence_path}/NG_Incidence_Table.csv")
incidence_per_1000 = pd.read_csv(f"{data_path}/Incidence Data/{country_code}_incidence_data_for_pipeline_DO_NOT_MODIFY.csv")
incidence_per_1000 = incidence_per_1000.dropna()
# incidence_per_1000["Region ID"] = incidence_per_1000["Region ID"].astype(int)
incidence_per_1000
# Out:
#          State  Region ID  Incidence Per Thousand Recorded in 2021  \
# 0        Benue        7.0                                    257.2
# 1  Cross_River        9.0                                    288.8
# 2       Ebonyi       11.0                                    371.5
# 3    Nassarawa       26.0                                    274.1
# 4      Plateau       32.0                                    286.5
# 5       Taraba       35.0                                    299.9
#
#   Population (2019 estimate, from Wikipedia, National Bureau of Statistics)  \
# 0                                          5,787,706
# 1                                          4,175,020
# 2                                          3,007,155
# 3                                          2,632,239
# 4                                          4,400,974
# 5                                          3,331,885
#
#   Population (2020 estimate from rasters)  Growth Rate (2019-2020)  \
# 0                               6,464,378                    1.117
# 1                               4,008,484                    0.960
# 2                               3,284,316                    1.092
# 3                               2,781,807                    1.057
# 4                               4,758,921                    1.081
# 5                               3,274,257                    0.983
#
#   Population (2021 target based on worldometers birth rate and wordpop raster counts)  \
# 0                                          6,601,202
# 1                                          4,093,327
# 2                                          3,353,832
# 3                                          2,840,686
# 4                                          4,859,648
# 5                                          3,343,560
#
#   Total Cases 2021 from projected population and observed incidence  \
# 0                                          1,697,829
# 1                                          1,182,153
# 2                                          1,245,948
# 3                                            778,632
# 4                                          1,392,289
# 5                                          1,002,734
#
#   Population (2024 target based on worldometers birth rate and wordpop raster counts)  \
# 0                                          7,028,225
# 1                                          4,358,119
# 2                                          3,570,786
# 3                                          3,024,446
# 4                                          5,174,011
# 5                                          3,559,850
#
#   Total Cases 2024 from projected population and observed incidence
# 0                                          1,807,659
# 1                                          1,258,625
# 2                                          1,326,547
# 3                                            829,001
# 4                                          1,482,354
# 5                                          1,067,599

# %%
data_df = pop_df.merge(incidence_per_1000, left_on="district_id", right_on="Region ID", how="left")
data_df
# Out:
#    district_id  init_population  final_population_2020  \
# 0            7        5042202.0              6464378.0
# 1            9        3126634.0              4008484.0
# 2           11        2561567.0              3284316.0
# 3           26        2170074.0              2781807.0
# 4           32        3712017.0              4758921.0
# 5           35        2554777.0              3274257.0
#
#    final_population_2024_projected        State  Region ID  \
# 0                     7.028493e+06        Benue        7.0
# 1                     4.358285e+06  Cross_River        9.0
# 2                     3.570922e+06       Ebonyi       11.0
# 3                     3.024562e+06    Nassarawa       26.0
# 4                     5.174209e+06      Plateau       32.0
# 5                     3.559986e+06       Taraba       35.0
#
#    Incidence Per Thousand Recorded in 2021  \
# 0                                    257.2
# 1                                    288.8
# 2                                    371.5
# 3                                    274.1
# 4                                    286.5
# 5                                    299.9
#
#   Population (2019 estimate, from Wikipedia, National Bureau of Statistics)  \
# 0                                          5,787,706
# 1                                          4,175,020
# 2                                          3,007,155
# 3                                          2,632,239
# 4                                          4,400,974
# 5                                          3,331,885
#
#   Population (2020 estimate from rasters)  Growth Rate (2019-2020)  \
# 0                               6,464,378                    1.117
# 1                               4,008,484                    0.960
# 2                               3,284,316                    1.092
# 3                               2,781,807                    1.057
# 4                               4,758,921                    1.081
# 5                               3,274,257                    0.983
#
#   Population (2021 target based on worldometers birth rate and wordpop raster counts)  \
# 0                                          6,601,202
# 1                                          4,093,327
# 2                                          3,353,832
# 3                                          2,840,686
# 4                                          4,859,648
# 5                                          3,343,560
#
#   Total Cases 2021 from projected population and observed incidence  \
# 0                                          1,697,829
# 1                                          1,182,153
# 2                                          1,245,948
# 3                                            778,632
# 4                                          1,392,289
# 5                                          1,002,734
#
#   Population (2024 target based on worldometers birth rate and wordpop raster counts)  \
# 0                                          7,028,225
# 1                                          4,358,119
# 2                                          3,570,786
# 3                                          3,024,446
# 4                                          5,174,011
# 5                                          3,559,850
#
#   Total Cases 2024 from projected population and observed incidence
# 0                                          1,807,659
# 1                                          1,258,625
# 2                                          1,326,547
# 3                                            829,001
# 4                                          1,482,354
# 5                                          1,067,599

# %%
data_df
# Out:
#    district_id  init_population  final_population_2020  \
# 0            7        5042202.0              6464378.0
# 1            9        3126634.0              4008484.0
# 2           11        2561567.0              3284316.0
# 3           26        2170074.0              2781807.0
# 4           32        3712017.0              4758921.0
# 5           35        2554777.0              3274257.0
#
#    final_population_2024_projected        State  Region ID  \
# 0                     7.028493e+06        Benue        7.0
# 1                     4.358285e+06  Cross_River        9.0
# 2                     3.570922e+06       Ebonyi       11.0
# 3                     3.024562e+06    Nassarawa       26.0
# 4                     5.174209e+06      Plateau       32.0
# 5                     3.559986e+06       Taraba       35.0
#
#    Incidence Per Thousand Recorded in 2021  \
# 0                                    257.2
# 1                                    288.8
# 2                                    371.5
# 3                                    274.1
# 4                                    286.5
# 5                                    299.9
#
#   Population (2019 estimate, from Wikipedia, National Bureau of Statistics)  \
# 0                                          5,787,706
# 1                                          4,175,020
# 2                                          3,007,155
# 3                                          2,632,239
# 4                                          4,400,974
# 5                                          3,331,885
#
#   Population (2020 estimate from rasters)  Growth Rate (2019-2020)  \
# 0                               6,464,378                    1.117
# 1                               4,008,484                    0.960
# 2                               3,284,316                    1.092
# 3                               2,781,807                    1.057
# 4                               4,758,921                    1.081
# 5                               3,274,257                    0.983
#
#   Population (2021 target based on worldometers birth rate and wordpop raster counts)  \
# 0                                          6,601,202
# 1                                          4,093,327
# 2                                          3,353,832
# 3                                          2,840,686
# 4                                          4,859,648
# 5                                          3,343,560
#
#   Total Cases 2021 from projected population and observed incidence  \
# 0                                          1,697,829
# 1                                          1,182,153
# 2                                          1,245,948
# 3                                            778,632
# 4                                          1,392,289
# 5                                          1,002,734
#
#   Population (2024 target based on worldometers birth rate and wordpop raster counts)  \
# 0                                          7,028,225
# 1                                          4,358,119
# 2                                          3,570,786
# 3                                          3,024,446
# 4                                          5,174,011
# 5                                          3,559,850
#
#   Total Cases 2024 from projected population and observed incidence
# 0                                          1,807,659
# 1                                          1,258,625
# 2                                          1,326,547
# 3                                            829,001
# 4                                          1,482,354
# 5                                          1,067,599

# %%
data_df.to_csv(f"{data_path}/population_incidence_per_district.csv", index=False)

print(f"Wrote population and incidence per district to {data_path}/population_incidence_per_district.csv")
# Out:
# Wrote population and incidence per district to data/population_incidence_per_district.csv

# %% [markdown]
# ### Birthrate from initial to calibration year based on initial population and final observed population

# %%
period = calibration_year - initial_year
population_diff = data_df[f'final_population_{calibration_year}_projected'] - data_df['init_population']
change_each_year = population_diff / period

# Build a neat summary table
result_df = data_df[["district_id", "init_population", f'final_population_{calibration_year}_projected']].copy()
result_df["population_diff"] = population_diff
result_df["change_per_year"] = change_each_year

# Formatters for nice printing
formatters = {
    "district_id": lambda x: f"{int(x)}",
    "init_population": lambda x: f"{x:,.0f}",
    f'final_population_{calibration_year}_projected': lambda x: f"{x:,.0f}",
    "population_diff": lambda x: f"{x:,.0f}",
    "change_per_year": lambda x: f"{x:,.2f}",
}

print(f"Population change per district over {period} years (average per year):\n")
print(result_df.to_string(index=False, formatters=formatters))
# Out:
# Population change per district over 13 years (average per year):
#
# district_id init_population final_population_2024_projected population_diff change_per_year
#           7       5,042,202                       7,028,493       1,986,291      152,791.62
#           9       3,126,634                       4,358,285       1,231,651       94,742.39
#          11       2,561,567                       3,570,922       1,009,355       77,642.72
#          26       2,170,074                       3,024,562         854,488       65,729.84
#          32       3,712,017                       5,174,209       1,462,192      112,476.31
#          35       2,554,777                       3,559,986       1,005,209       77,323.74
